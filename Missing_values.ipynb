# %%
#isnull()
#notnull()
#fillna()

import pandas as pd
import numpy as np

#dictionary of list
dict = {'First score':[100,90,np.nan,95],
         'Second score':[30,45,56,np.nan],
         'Third score':[np.nan,40,80,98]}

#creating a dataframe from list
df = pd.DataFrame(dict)

df

#using isnull function(to identify what are the cell is null or not  --> give true if there is null otherwise it will give false)
df.isnull()
# Out:
#    First score  Second score  Third score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
import pandas as pd

data = pd.read_csv('C:\\Users\\Athiban\\Desktop\\Kee\\Bigg_Boss_India.csv')
data.isnull()
# Out:
#      Language  Season Number   Name  Profession  Gender  Entry Date  \
# 0       False          False  False       False   False       False
# 1       False          False  False       False   False       False
# 2       False          False  False       False   False       False
# 3       False          False  False       False   False       False
# 4       False          False  False       False   False       False
# ..        ...            ...    ...         ...     ...         ...
# 738     False          False  False       False   False       False
# 739     False          False  False       False   False        True
# 740     False          False  False       False   False        True
# 741     False          False  False       False   False        True
# 742     False          False  False       False   False        True
#
#      Elimination Date  Elimination Week Number  Wild Card  Season Length  ...  \
# ...

# %%
#count the missing cells of each column 

data.isnull().sum()
# Out:
# Language                                0
# Season Number                           0
# Name                                    0
# Profession                              0
# Gender                                  0
# Entry Date                            111
# Elimination Date                      599
# Elimination Week Number               154
# Wild Card                               0
# Season Length                           0
# Number of Housemates                    0
# Season Start Date                       0
# Season End Date                         0
# Host Name                               0
# Guest Host Name                       653
# Prize Money (INR)                      41
# Broadcasted By                          0
# Average TRP                           261
# Number of Evictions Faced              18
# Number of re-entries                    0
# Number of times elected as Captain     33
# Social Media Popularity               645
# ...

# %%
#filtering only the winner column 

bool_series = pd.isnull(data["Winner"])

#filtering the data
#displaying data only with winner = Nan

data[bool_series]
# Out:
#     Language  Season Number                Name           Profession  \
# 262    Hindi             15      Jay Bhanushali                Actor
# 263    Hindi             15        Karan Kundra           Soap Actor
# 265    Hindi             15        Nishant Bhat        Choreographer
# 266    Hindi             15     Pratik Sehajpal  Reality Show Alumni
# 269    Hindi             15        Simba Nagpal           Soap Actor
# 270    Hindi             15    Tejasswi Prakash         Soap Actress
# 271    Hindi             15           Umar Riaz               Doctor
# 273    Hindi             15       Vishal Kotian           Soap Actor
# 274    Hindi             15        Rajiv Adatia                Model
# 276    Hindi             15         Neha Bhasin               Singer
# 493   Telugu              5                Anee        Choreographer
# 496   Telugu              5               Kajal         Radio Jockey
# 499   Telugu              5              Maanas           Soap Actor
# ...

# %%
data.notnull()
# Out:
#      Language  Season Number  Name  Profession  Gender  Entry Date  \
# 0        True           True  True        True    True        True
# 1        True           True  True        True    True        True
# 2        True           True  True        True    True        True
# 3        True           True  True        True    True        True
# 4        True           True  True        True    True        True
# ..        ...            ...   ...         ...     ...         ...
# 738      True           True  True        True    True        True
# 739      True           True  True        True    True       False
# 740      True           True  True        True    True       False
# 741      True           True  True        True    True       False
# 742      True           True  True        True    True       False
#
#      Elimination Date  Elimination Week Number  Wild Card  Season Length  ...  \
# 0               False                     True       True           True  ...
# ...

# %%
df.notnull()
# Out:
#    First score  Second score  Third score
# 0         True          True        False
# 1         True          True         True
# 2        False          True         True
# 3         True         False         True

# %%
#fillna() #this function is used to fill the missing values 

df.fillna(0) # 0 will be filled in the missing cells
# Out:
#    First score  Second score  Third score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_56892/400103009.py in <module>
# ----> 1 print(df)
#
# NameError: name 'df' is not defined

# %%
df.fillna(method = 'pad') #pad thechniqie will be used for taking previous values and filled here
# Out:
#    First score  Second score  Third score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         90.0          56.0         80.0
# 3         95.0          56.0         98.0

# %%
df.fillna(method = 'bfill') #it will take next cell from the empty cell / null cell and filled here called backward filling
# Out:
#    First score  Second score  Third score
# 0        100.0          30.0         40.0
# 1         90.0          45.0         40.0
# 2         95.0          56.0         80.0
# 3         95.0           NaN         98.0

# %%
df.fillna(method = 'ffill') #it will take the previous cell values and filled here its called forward filling
# Out:
#    First score  Second score  Third score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         90.0          56.0         80.0
# 3         95.0          56.0         98.0

# %%
#if you want to overwrite completely from your data use inplace = True
data["Winner"].head(10)
data["Winner"].fillna(10, inplace = True)
data
# Out:
#       Language  Season Number                      Name       Profession  \
# 0        Hindi              1                 Amit Sadh       Soap Actor
# 1        Hindi              1             Anupama Verma            Model
# 2        Hindi              1                Aryan Vaid   Pageant Winner
# 3        Hindi              1             Bobby Darling             LGBT
# 4        Hindi              1             Carol Gracias            Model
# ..         ...            ...                       ...              ...
# 738  Malayalam              3              Soorya Menon            Model
# 739  Malayalam              3  Firoz Khan & Sajna Firoz  Actor & Actress
# 740  Malayalam              3       Michelle Ann Daniel          Actress
# 741  Malayalam              3              Angel Thomas            Model
# 742  Malayalam              3            Remya Panickar          Actress
#
#           Gender Entry Date Elimination Date  Elimination Week Number  \
# ...

# %%
data["Winner"].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 738    True
# 739    True
# 740    True
# 741    True
# 742    True
# Name: Winner, Length: 743, dtype: bool

# %%
#all the missing values will be replace (nan values in data) by -99

data.replace(to_replace = np.nan, value = -99)
# Out:
#       Language  Season Number                      Name       Profession  \
# 0        Hindi              1                 Amit Sadh       Soap Actor
# 1        Hindi              1             Anupama Verma            Model
# 2        Hindi              1                Aryan Vaid   Pageant Winner
# 3        Hindi              1             Bobby Darling             LGBT
# 4        Hindi              1             Carol Gracias            Model
# ..         ...            ...                       ...              ...
# 738  Malayalam              3              Soorya Menon            Model
# 739  Malayalam              3  Firoz Khan & Sajna Firoz  Actor & Actress
# 740  Malayalam              3       Michelle Ann Daniel          Actress
# 741  Malayalam              3              Angel Thomas            Model
# 742  Malayalam              3            Remya Panickar          Actress
#
#           Gender Entry Date Elimination Date  Elimination Week Number  \
# ...

# %%
data.isnull().sum()
# Out:
# Language                                0
# Season Number                           0
# Name                                    0
# Profession                              0
# Gender                                  0
# Entry Date                            111
# Elimination Date                      599
# Elimination Week Number               154
# Wild Card                               0
# Season Length                           0
# Number of Housemates                    0
# Season Start Date                       0
# Season End Date                         0
# Host Name                               0
# Guest Host Name                       653
# Prize Money (INR)                      41
# Broadcasted By                          0
# Average TRP                           261
# Number of Evictions Faced              18
# Number of re-entries                    0
# Number of times elected as Captain     33
# Social Media Popularity               645
# ...

# %%
#manually imput missing values with numpy
from pandas import read_csv
from numpy import nan

#fill missing values with mean column values , here using std

data.fillna(data.std(),inplace = True)

#count the number of NAN values in each column 
print(data.isnull().sum())
# Out:
# Language                                0
# Season Number                           0
# Name                                    0
# Profession                              0
# Gender                                  0
# Entry Date                            111
# Elimination Date                      599
# Elimination Week Number                 0
# Wild Card                               0
# Season Length                           0
# Number of Housemates                    0
# Season Start Date                       0
# Season End Date                         0
# Host Name                               0
# Guest Host Name                       653
# Prize Money (INR)                      41
# Broadcasted By                          0
# Average TRP                             0
# Number of Evictions Faced               0
# Number of re-entries                    0
# Number of times elected as Captain      0
# Social Media Popularity                 0
# ...

# %%
import pandas as pd

df1 = pd.DataFrame({"A":[12,4,5,None,1],
                    "B":[None,2,54,3,None],
                    "C":[20,16,None,3,8],
                    "D":[14,3,None,None,6]})
df1
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   NaN   NaN
# 3   NaN   3.0   3.0   NaN
# 4   1.0   NaN   8.0   6.0

# %%
#to interpolate the missing values

df1.interpolate(method ='linear', limit_direction ='forward')
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   9.5   4.0
# 3   3.0   3.0   3.0   5.0
# 4   1.0   3.0   8.0   6.0

# %%
df1
df1.interpolate(method ='linear', limit_direction ='backward')
# Out:
#       A     B     C     D
# 0  12.0   2.0  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   9.5   4.0
# 3   3.0   3.0   3.0   5.0
# 4   1.0   NaN   8.0   6.0

# %%
#Delete Method 

#dropna() - this will drop the rows which containing the missing cells
import pandas as pd
import numpy as np

dict1 = {'first':[100,90,np.nan,95],
         'second':[30,np.nan,45,56],
         'third':[52,40,80,98],
         'fourth':[np.nan,np.nan,np.nan,65]}
df2 = pd.DataFrame(dict1)
df2
# Out:
#    first  second  third  fourth
# 0  100.0    30.0     52     NaN
# 1   90.0     NaN     40     NaN
# 2    NaN    45.0     80     NaN
# 3   95.0    56.0     98    65.0

# %%
df2.dropna()
# Out:
#    first  second  third  fourth
# 3   95.0    56.0     98    65.0

# %%
#how = 'all' " if all the cells are missing in the row then drop it otherwise dont drop it"
print(df2)
df2.dropna(how = 'all')
# Out:
#    first  second  third  fourth
# 0  100.0    30.0     52     NaN
# 1   90.0     NaN     40     NaN
# 2    NaN    45.0     80     NaN
# 3   95.0    56.0     98    65.0
#    first  second  third  fourth
# 0  100.0    30.0     52     NaN
# 1   90.0     NaN     40     NaN
# 2    NaN    45.0     80     NaN
# 3   95.0    56.0     98    65.0

# %%
import pandas as pd
import numpy as np

dict2 = {'first':[100,np.nan,np.nan,95],
         'second':[30,np.nan,45,56],
         'third':[52,np.nan,80,98],
         'fourth':[60,np.nan,68,65]}
df3 = pd.DataFrame(dict2)
print(df3)
df3.dropna(how = 'all')
# Out:
#    first  second  third  fourth
# 0  100.0    30.0   52.0    60.0
# 1    NaN     NaN    NaN     NaN
# 2    NaN    45.0   80.0    68.0
# 3   95.0    56.0   98.0    65.0
#    first  second  third  fourth
# 0  100.0    30.0   52.0    60.0
# 2    NaN    45.0   80.0    68.0
# 3   95.0    56.0   98.0    65.0

# %%
#column level deletion 

df3.dropna(axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
import pandas as pd
import numpy as np

dict1 = {'first':[100,np.nan,np.nan,95],
         'second':[30,np.nan,45,56],
         'third':[52,np.nan,80,98],
         'fourth':[60,67,68,65]}
df2 = pd.DataFrame(dict1)
df2
df2.dropna(axis=1)

#axis = 1--> means column (here 1st column has 2 missing values, 2nd col has 1 missing values, 3rd has 1 missing values, 4th has nothing, hence it will reflect)
# Out:
#    fourth
# 0      60
# 1      67
# 2      68
# 3      65

# %%
#axis = 0 means row wise, how = any means if any one of the missing cells there is a row then drop the row
old_data = df3
new_data = df3.dropna(axis = 0, how = 'any')
print(old_data)
print(new_data)
# Out:
#    first  second  third  fourth
# 0  100.0    30.0   52.0    60.0
# 1    NaN     NaN    NaN     NaN
# 2    NaN    45.0   80.0    68.0
# 3   95.0    56.0   98.0    65.0
#    first  second  third  fourth
# 0  100.0    30.0   52.0    60.0
# 3   95.0    56.0   98.0    65.0

# %%
print("old data frame length:", len(old_data))
print("new data frame length:", len(new_data))
print("No of rows atleast 1 Na values:", (len(old_data)-len(new_data)))
# Out:
# old data frame length: 4
# new data frame length: 2
# No of rows atleast 1 Na values: 2

# %%
Algorithms that support Missing values
    K- Nearest Neighbors
    Naive Bayes
    
#use the above alg's only if you have missing values in your data otherwise the data wont accept your alg's

# %%
# !pip install scikit-Learn

# %%
#example of imputing missing values using scikit learn
from numpy import nan
from numpy import isnan
from pandas import read_csv
from sklearn.impute import SimpleImputer

#Simpleimputer is a method/API which is available in sklearn.impute   -> it has 2 arguments (missing values and stratergy)

values = new_data.values
#define the imputer
imputer = SimpleImputer(missing_values=nan, strategy='mean')
#transform the dataset
transformed_values = imputer.fit_transform(values)
#count the number of NaN values in each column
print('Missing: %d' % isnan(transformed_values).sum())
# Out:
# Missing: 0

# %%
# !pip install missingno

# %%
#program to visualize missing values in dataset

#importing the libraries

import pandas as pd
import missingno as msno

msno.bar(data)
# Out:
# <AxesSubplot:>

# %%
#heatmap -> to find the correlation for the missing values

#visualize the correlation between the number of 
#missing values in different columns as a heatmap
msno.heatmap(data)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(data)
#matrix - to display which cells are missing
# Out:
# <AxesSubplot:>

# %%
msno.dendrogram(data)

#dendrogram -> to see the correlsious
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np

dict2 = {'first':[100,np.nan,np.nan,95],
         'second':[30,np.nan,45,56],
         'third':[52,np.nan,80,98],
         'fourth':[60,np.nan,68,65]}
df3 = pd.DataFrame(dict2)
df3
# Out:
#    first  second  third  fourth
# 0  100.0    30.0   52.0    60.0
# 1    NaN     NaN    NaN     NaN
# 2    NaN    45.0   80.0    68.0
# 3   95.0    56.0   98.0    65.0

# %%
from sklearn.impute import KNNImputer
train_knn = train.copy(deep=True)

knn_imputer = KNNImputer(n_neighbors=2,weight="uniform")
train_knn['Winner'] = knn_imputer.fit_transform(train_knn[['Winner']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36092/2501663215.py in <module>
#       1 from sklearn.impute import KNNImputer
# ----> 2 train_knn = train.copy(deep=True)
#       3
#       4 knn_imputer = KNNImputer(n_neighbors=2,weight="uniform")
#       5 train_knn['Winner'] = knn_imputer.fit_transform(train_knn[['Winner']])
#
# NameError: name 'train' is not defined

# %%
import numpy as np
from sklearn.impute import KNNImputer


imputer = KNNImputer(n_neighbors=2)
print(imputer.fit_transform(df3))
df3
# Out:
# [[100.          30.          52.          60.        ]
#  [ 97.5         43.66666667  76.66666667  64.33333333]
#  [ 97.5         45.          80.          68.        ]
#  [ 95.          56.          98.          65.        ]]
#    first  second  third  fourth
# 0  100.0    30.0   52.0    60.0
# 1    NaN     NaN    NaN     NaN
# 2    NaN    45.0   80.0    68.0
# 3   95.0    56.0   98.0    65.0

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

mice_imputer = IterativeImputer()
mice_imputer.fit_transform(old_data)
# Out:
# array([[100.        ,  30.        ,  52.        ,  60.        ],
#        [ 97.31688561,  43.66666667,  76.66666667,  64.33333333],
#        [ 96.95065682,  45.        ,  80.        ,  68.        ],
#        [ 95.        ,  56.        ,  98.        ,  65.        ]])
